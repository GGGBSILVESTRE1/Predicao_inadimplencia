# %%
import kagglehub
from src.config import DATA_DIR

# Download latest version
path = kagglehub.competition_download('home-credit-default-risk', output_dir=DATA_DIR)

print("Path to competition files:", path)
# Out:
# ...
# 100%|██████████| 688M/688M [00:31<00:00, 23.2MB/s]
# Extracting files...
# Path to competition files: c:\Users\Guilherme\Desktop\Estudos\Código\Analise_credito\notebooks\data
